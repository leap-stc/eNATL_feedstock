# %%
import xarray as xr
from dask.distributed import Client
from rechunker import rechunk
from zarr import consolidate_metadata

# %%
client = Client(n_workers=16)
client
# Out:
# <Client: 'tcp://127.0.0.1:43589' processes=16 threads=16, memory=125.80 GiB>

# %%
combined_ds = xr.open_dataset(
    "gs://leap-persistent/norlandrhagen/references/enatl_600m.parquet",
    engine="kerchunk",
    chunks={},
)

# %%
rechunking_plan = rechunk(
    source=combined_ds,
    target_chunks={"time": 3, "y": 2365, "x": 4177},
    temp_store="temp/store.zarr",
    max_mem="1GB",
    target_store="gs://leap-persistent/data-library/feedstocks/eNATL_feedstock/eNATL600m-BLBT02.zarr",
)

# %%
consolidate_metadata(
    "gs://leap-persistent/data-library/feedstocks/eNATL_feedstock/eNATL600m-BLBT02.zarr"
)
# Out:
# <zarr.hierarchy.Group '/'>

# %%
ds = xr.open_zarr(
    "gs://leap-persistent/data-library/feedstocks/eNATL_feedstock/eNATL600m-BLBT02.zarr",
    consolidated=True,
)

# %%
ds
# Out:
# <xarray.Dataset> Size: 173GB
# Dimensions:   (y: 4729, x: 8354, time: 365)
# Coordinates:
#     nav_lat   (y, x) float32 158MB dask.array<chunksize=(2365, 4177), meta=np.ndarray>
#     nav_lon   (y, x) float32 158MB dask.array<chunksize=(2365, 4177), meta=np.ndarray>
# Dimensions without coordinates: y, x, time
# Data variables:
#     vosaline  (time, y, x) float32 58GB dask.array<chunksize=(3, 2365, 4177), meta=np.ndarray>
#     votemper  (time, y, x) float32 58GB dask.array<chunksize=(3, 2365, 4177), meta=np.ndarray>
#     vovecrtz  (time, y, x) float32 58GB dask.array<chunksize=(3, 2365, 4177), meta=np.ndarray>
# Attributes:
#     CASE:                       N/A
#     CONFIG:                     N/A
#     NCO:                        netCDF Operators version 4.7.4-alpha04 (http:...
#     history:                    Wed Sep 11 14:17:27 2024: ncrename -d t,time ...
#     history_of_appended_files:  Wed Sep 11 14:17:04 2024: Appended file /mnt/...
#     nco_openmp_thread_number:   1
#     output_frequency:           N/A
#     start_date:                 -1
